# %%
import os
import umap
import random
import sklearn
import pandas as pd
import numpy as np
import seaborn as sns
import palettable as ptable#python颜色库

from sklearn.metrics import f1_score, accuracy_score

import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
from torch.autograd import Variable

from matplotlib import pyplot as plt

from sklearn.manifold import TSNE
from sklearn.cluster import KMeans, AgglomerativeClustering, DBSCAN, SpectralClustering, MeanShift

from scipy.cluster import hierarchy  #用于进行层次聚类，话层次聚类图的工具包
from scipy import cluster 


# %matplotlib inline

# %%
train_data_file = "./data_HC/menon_train_data.csv"
train_label_file = "./data_HC/menon_train_label.csv"
valid_data_file = "./data_HC/menon_validation_data.csv"
valid_label_file = "./data_HC/menon_validation_label.csv"
test_data_file = "./data_HC/lukowski_test_data.csv"
test_label_file = None

# %%
classes_tree = pd.read_csv("./data_HC/classes_tree.csv").fillna("Unknown")
classes_tree
# Out:
#        Root          Level 1           Level 2             Level 3  \
# 0       Eye          Unknown           Unknown             Unknown
# 1   Unknown       Nerve cell           Unknown             Unknown
# 2   Unknown          Unknown            Neuron             Unknown
# 3   Unknown          Unknown           Unknown  Photoreceptor cell
# 4   Unknown          Unknown           Unknown             Unknown
# 5   Unknown          Unknown           Unknown             Unknown
# 6   Unknown          Unknown           Unknown        Bipolar cell
# 7   Unknown          Unknown           Unknown             Unknown
# 8   Unknown          Unknown           Unknown             Unknown
# 9   Unknown          Unknown           Unknown       Ganglion cell
# 10  Unknown          Unknown           Unknown             Unknown
# 11  Unknown          Unknown   Neuroglial cell             Unknown
# 12  Unknown          Unknown           Unknown         Muller cell
# 13  Unknown          Unknown           Unknown           Microglia
# 14  Unknown  Epithelial cell           Unknown             Unknown
# 15  Unknown          Unknown  Endothelial cell             Unknown
#
#                   Level 4
# 0                 Unknown
# 1                 Unknown
# 2                 Unknown
# 3                 Unknown
# 4                Rod cell
# 5               Cone cell
# 6                 Unknown
# 7           Amacrine cell
# 8         Horizontal cell
# 9                 Unknown
# 10  Retinal ganglion cell
# 11                Unknown
# 12                Unknown
# 13                Unknown
# 14                Unknown
# 15                Unknown

# %%
n_levels = classes_tree.shape[1]
n_levels

BATCH_SIZE = 1024
N_EPOCHS = 60

# %%
def Get_level_label(n_levels = n_levels, classes_tree = classes_tree):
    level_label = dict()
    level_label_value = dict()
    for i in range(n_levels):
        labels = np.unique(classes_tree.iloc[:,i])
        level_label[i] = dict()
        level_label_value[i] = dict()
        for j in range(labels.shape[0]):
            level_label[i][labels[j]] = np.eye(labels.shape[0])[j]
            level_label_value[i][j] = labels[j]
    return level_label, level_label_value

level_label, level_label_value = Get_level_label(n_levels, classes_tree)
print(level_label)
print(level_label_value)
# Out:
# {0: {'Eye': array([1., 0.]), 'Unknown': array([0., 1.])}, 1: {'Epithelial cell': array([1., 0., 0.]), 'Nerve cell': array([0., 1., 0.]), 'Unknown': array([0., 0., 1.])}, 2: {'Endothelial cell': array([1., 0., 0., 0.]), 'Neuroglial cell': array([0., 1., 0., 0.]), 'Neuron': array([0., 0., 1., 0.]), 'Unknown': array([0., 0., 0., 1.])}, 3: {'Bipolar cell': array([1., 0., 0., 0., 0., 0.]), 'Ganglion cell': array([0., 1., 0., 0., 0., 0.]), 'Microglia': array([0., 0., 1., 0., 0., 0.]), 'Muller cell': array([0., 0., 0., 1., 0., 0.]), 'Photoreceptor cell': array([0., 0., 0., 0., 1., 0.]), 'Unknown': array([0., 0., 0., 0., 0., 1.])}, 4: {'Amacrine cell': array([1., 0., 0., 0., 0., 0.]), 'Cone cell': array([0., 1., 0., 0., 0., 0.]), 'Horizontal cell': array([0., 0., 1., 0., 0., 0.]), 'Retinal ganglion cell': array([0., 0., 0., 1., 0., 0.]), 'Rod cell': array([0., 0., 0., 0., 1., 0.]), 'Unknown': array([0., 0., 0., 0., 0., 1.])}}
# {0: {0: 'Eye', 1: 'Unknown'}, 1: {0: 'Epithelial cell', 1: 'Nerve cell', 2: 'Unknown'}, 2: {0: 'Endothelial cell', 1: 'Neuroglial cell', 2: 'Neuron', 3: 'Unknown'}, 3: {0: 'Bipolar cell', 1: 'Ganglion cell', 2: 'Microglia', 3: 'Muller cell', 4: 'Photoreceptor cell', 5: 'Unknown'}, 4: {0: 'Amacrine cell', 1: 'Cone cell', 2: 'Horizontal cell', 3: 'Retinal ganglion cell', 4: 'Rod cell', 5: 'Unknown'}}

# %%
train_data_df = pd.read_csv(train_data_file, index_col=0).fillna(-1)
train_label_df = pd.read_csv(train_label_file, index_col=0).fillna("Unknown")
valid_data_df = pd.read_csv(valid_data_file, index_col=0).fillna(-1)
valid_label_df = pd.read_csv(valid_label_file, index_col=0).fillna("Unknown")
test_data_df = pd.read_csv(test_data_file, index_col=0).fillna(-1)
test_label_df = None

# %%
print(train_label_df.shape)
# Out:
# (14346, 4)

# %%
def GetAdjacency(data_df, k = 10, epsilon = None):
    data = np.array(data_df)
    data = data/np.sqrt(np.sum(data**2, axis=1, keepdims=True))
    Adjacency = np.dot(data, data.T)
    if(epsilon is None):
        n = data_df.shape[0]
        Adjacency_sort = -np.sort(-Adjacency.reshape(-1))
        epsilon = Adjacency_sort[k*n-1]

    idx = np.where(Adjacency<epsilon)
    Adjacency[idx] = 0
    return epsilon, Adjacency

# %%
epsilon, train_Adjacency = GetAdjacency(train_data_df, k = 11, epsilon = None)

# %%
print(epsilon)
print(train_Adjacency.shape)
np.where(train_Adjacency[11]>=epsilon)[0].shape
# Out:
# 0.7636975165273994
# (14346, 14346)
# (1,)

# %%
mean = np.mean(train_data_df, axis = 0)

# %%
MEAN = 0
STD = 0
class CellDataset(Dataset):
    def __init__(self, data_df, label_df, is_train = True, is_test = False, mean = None, std = None):
        self.data_df = data_df
        self.label_df = label_df
        self.mean = None
        self.std = None
        self.is_train = is_train
        self.is_test = is_test
        if(is_train):
            self.mean = np.mean(data_df, axis = 0)
            self.std = np.std(data_df, axis = 0)
        else:
            self.mean = mean
            self.std = std
        #self.data_df = (self.data_df-self.mean)/(self.std+1e-12)
        MEAN = self.mean
        STD = self.std
    def __len__(self):
        return self.data_df.shape[0]
    
    def __getitem__(self, idx):
        data = self.data_df.iloc[idx,:].astype(np.float32)
        data = torch.from_numpy(np.array(data))
        labels = int(-1)
        if(not self.is_test):
            labels = list(self.label_df.iloc[idx,:])
            for i in range(len(labels)):
                labels[i] = level_label[i+1][labels[i]]
                labels[i] = torch.from_numpy(labels[i].astype(np.uint8))
                labels[i] = labels[i].unsqueeze(-1)

        return data, labels

# %%
class DenseCrossEntropy(nn.Module):

    def __init__(self):
        super(DenseCrossEntropy, self).__init__()
        
        
    def forward(self, logits, labels):
        logits = logits.float()
        labels = labels.float()
        
        logprobs = F.log_softmax(logits, dim=-1)
        
        loss = -labels * logprobs
        loss = loss.sum(-1)

        return loss.mean()

# %%
class CellModel(nn.Module):
    def __init__(self, input_size=2000, output_size=256):
        super().__init__()
        self.fc1 = nn.Linear(input_size, 512)
        nn.init.kaiming_normal_(self.fc1.weight) # OPTIONAL
        self.fc2 = nn.Linear(512, 256)
        nn.init.kaiming_normal_(self.fc2.weight) # OPTIONAL
        #self.fc3 = nn.Linear(512, 256)
        #nn.init.kaiming_normal_(self.fc3.weight) # OPTIONAL
        self.fc_gcn1 = nn.Linear(input_size, input_size)
        nn.init.kaiming_normal_(self.fc_gcn1.weight) # OPTIONAL
        self.fc_gcn2 = nn.Linear(input_size, input_size)
        nn.init.kaiming_normal_(self.fc_gcn2.weight) # OPTIONAL
        #self.fc6 = nn.Linear(64, 32)
        #nn.init.kaiming_normal_(self.fc3.weight) # OPTIONAL
               
    def forward(self, adj, x):
        x = F.relu(self.fc_gcn1(torch.mm(adj, x)))
        x = F.relu(self.fc_gcn2(torch.mm(adj, x)))
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        ##output1 = F.relu(self.fc3(x))
        #output2 = F.relu(self.fc4(output1))
        #output3 = F.relu(self.fc5(output2))
        #output4 = F.relu(self.fc6(output3))
        return x

# %%
dataset_train = CellDataset(train_data_df, train_label_df, is_train = True)
dataloader_train = DataLoader(dataset_train, batch_size=BATCH_SIZE, num_workers=1, shuffle=True)
dataset_valid = CellDataset(valid_data_df, valid_label_df, is_train = False, mean = MEAN, std = STD)
dataloader_valid = DataLoader(dataset_valid, batch_size=BATCH_SIZE, num_workers=1, shuffle=False)

# %%
dataset_test = CellDataset(test_data_df, test_label_df, is_train = False, is_test = True, mean = MEAN, std = STD)
dataloader_test = DataLoader(dataset_test, batch_size=BATCH_SIZE, num_workers=1, shuffle=False)

# %%
device = torch.device("cuda:0")
model = CellModel().to(device)

classifiers = []
#in_sizes = [0, 256, 128, 64, 32]
for item in level_label:
    if(item > 0):
        classifiers.append(nn.Linear(256, len(level_label[item])))
        nn.init.kaiming_normal_(classifiers[item-1].weight) # OPTIONAL
        classifiers[item-1] = classifiers[item-1].to(device)
        print(classifiers[item-1])
criterion = DenseCrossEntropy()
plist = [{'params': model.parameters(), 'lr': 5e-5}]
optimizer = optim.Adam(plist, lr=5e-5)
# Out:
# Linear(in_features=256, out_features=3, bias=True)
# Linear(in_features=256, out_features=4, bias=True)
# Linear(in_features=256, out_features=6, bias=True)
# Linear(in_features=256, out_features=6, bias=True)

# %%
model
# Out:
# CellModel(
#   (fc1): Linear(in_features=2000, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=256, bias=True)
#   (fc_gcn1): Linear(in_features=2000, out_features=2000, bias=True)
#   (fc_gcn2): Linear(in_features=2000, out_features=2000, bias=True)
# )

# %%
def train(model = model, classifiers = classifiers, criterion = criterion, optimizer = optimizer, dataloader = dataloader_train):
    loss_list = []
    accu_list = ([],[],[],[])
    f1_list = ([],[],[],[])
    for epoch in range(N_EPOCHS):
        model.train()
        tr_loss = 0
        
        tr_preds = []
        tr_labels = []
        for i in range(len(classifiers)):
            tr_preds.append(None)
            tr_labels.append(None)
        
        for step, batch in enumerate(dataloader_train):
            data = batch[0]
            eps, adj = GetAdjacency(data, 11, epsilon)
            data = data.to(device)
            adj = torch.from_numpy(adj).to(device)
            label = batch[1]
            for i in range(len(label)):
                label[i] = label[i].to(device)
                if tr_labels[i] is None:
                    tr_labels[i] = label[i].clone().squeeze(-1).data.cpu().argmax(dim=1)
                else:
                    tr_labels[i] = torch.cat((tr_labels[i], label[i].clone().squeeze(-1).data.cpu().argmax(dim=1)), dim=0)
            
                
            output = model(adj, data)
            loss = None
            for i in range(len(classifiers)):
                result = classifiers[i](output)
                if(loss is None):
                    loss = 2**(i)*criterion(result, label[i].squeeze(-1))
                else:
                    loss += 2**(i)*criterion(result, label[i].squeeze(-1))
    
                preds = torch.softmax(result, dim=1).data.cpu().argmax(dim=1)
                if(tr_preds[i] is None):
                    tr_preds[i] = preds
                else:
                    tr_preds[i] = torch.cat((tr_preds[i], preds), dim=0)
                    
            loss.backward()
            tr_loss += loss.item()
            optimizer.step()
            optimizer.zero_grad()
            loss_list.append(loss.data.cpu().numpy())
            print("Epoch %d, step %d, loss = %.4f"%(epoch, step, loss))
            
        level_accu = []
        level_f1 = []
        for i in range(len(classifiers)):
            level_f1.append(f1_score(tr_labels[i], tr_preds[i], average="macro"))
            level_accu.append(accuracy_score(tr_labels[i], tr_preds[i]))
            
            accu_list[i].append(level_accu[i])
            f1_list[i].append(level_f1[i])
            print("Epoch %d, level%d, accu = %.4f, f1_score = %.4f"%(epoch, i+1, level_accu[i], level_f1[i]))
        print("------------------------------------------------------------------")
    return loss_list, accu_list, f1_list

# %%
loss_list, accu_list, f1_list = train()
# Out:
# Epoch 0, step 0, loss = 410.3021
# Epoch 0, step 1, loss = 94.2251
# Epoch 0, step 2, loss = 31.6920
# Epoch 0, step 3, loss = 20.6597
# Epoch 0, step 4, loss = 18.6975
# Epoch 0, step 5, loss = 17.7206
# Epoch 0, step 6, loss = 17.0756
# Epoch 0, step 7, loss = 16.7714
# Epoch 0, step 8, loss = 16.6153
# Epoch 0, step 9, loss = 15.7479
# Epoch 0, step 10, loss = 14.7416
# Epoch 0, step 11, loss = 14.0559
# Epoch 0, step 12, loss = 13.8604
# Epoch 0, step 13, loss = 12.9679
# Epoch 0, step 14, loss = 14.5222
# Epoch 0, level1, accu = 0.4473, f1_score = 0.2062
# Epoch 0, level2, accu = 0.8584, f1_score = 0.4084
# Epoch 0, level3, accu = 0.4517, f1_score = 0.2976
# Epoch 0, level4, accu = 0.5857, f1_score = 0.2122
# ------------------------------------------------------------------
# Epoch 1, step 0, loss = 11.5012
# Epoch 1, step 1, loss = 11.4188
# Epoch 1, step 2, loss = 11.2790
# Epoch 1, step 3, loss = 10.6781
# Epoch 1, step 4, loss = 10.5854
# Epoch 1, step 5, loss = 10.0694
# Epoch 1, step 6, loss = 10.3842
# Epoch 1, step 7, loss = 9.8671
# Epoch 1, step 8, loss = 10.1528
# Epoch 1, step 9, loss = 9.7813
# Epoch 1, step 10, loss = 8.9217
# Epoch 1, step 11, loss = 8.5505
# Epoch 1, step 12, loss = 8.4870
# Epoch 1, step 13, loss = 8.7042
# Epoch 1, step 14, loss = 8.7067
# Epoch 1, level1, accu = 0.9962, f1_score = 0.3327
# Epoch 1, level2, accu = 0.9240, f1_score = 0.5972
# Epoch 1, level3, accu = 0.7993, f1_score = 0.4712
# Epoch 1, level4, accu = 0.8002, f1_score = 0.3062
# ------------------------------------------------------------------
# Epoch 2, step 0, loss = 7.7230
# Epoch 2, step 1, loss = 8.0444
# Epoch 2, step 2, loss = 7.4193
# Epoch 2, step 3, loss = 7.2501
# Epoch 2, step 4, loss = 6.7335
# Epoch 2, step 5, loss = 6.7885
# Epoch 2, step 6, loss = 6.7234
# Epoch 2, step 7, loss = 6.1132
# Epoch 2, step 8, loss = 6.4571
# Epoch 2, step 9, loss = 6.1424
# Epoch 2, step 10, loss = 5.5183
# Epoch 2, step 11, loss = 5.9501
# Epoch 2, step 12, loss = 5.5690
# Epoch 2, step 13, loss = 5.4714
# Epoch 2, step 14, loss = 5.2698
# Epoch 2, level1, accu = 0.9984, f1_score = 0.4996
# Epoch 2, level2, accu = 0.9668, f1_score = 0.7370
# Epoch 2, level3, accu = 0.8684, f1_score = 0.7126
# Epoch 2, level4, accu = 0.8490, f1_score = 0.3803
# ------------------------------------------------------------------
# Epoch 3, step 0, loss = 5.2261
# Epoch 3, step 1, loss = 4.7780
# Epoch 3, step 2, loss = 4.9117
# Epoch 3, step 3, loss = 4.8575
# Epoch 3, step 4, loss = 4.6251
# Epoch 3, step 5, loss = 4.3030
# Epoch 3, step 6, loss = 4.6152
# Epoch 3, step 7, loss = 4.2084
# Epoch 3, step 8, loss = 4.2721
# Epoch 3, step 9, loss = 4.0357
# Epoch 3, step 10, loss = 3.9260
# Epoch 3, step 11, loss = 3.7413
# Epoch 3, step 12, loss = 3.6331
# Epoch 3, step 13, loss = 3.2455
# Epoch 3, step 14, loss = 4.7932
# Epoch 3, level1, accu = 0.9984, f1_score = 0.4996
# Epoch 3, level2, accu = 0.9849, f1_score = 0.9062
# Epoch 3, level3, accu = 0.9158, f1_score = 0.8151
# Epoch 3, level4, accu = 0.9018, f1_score = 0.5803
# ------------------------------------------------------------------
# Epoch 4, step 0, loss = 3.3704
# Epoch 4, step 1, loss = 3.2668
# Epoch 4, step 2, loss = 3.2729
# Epoch 4, step 3, loss = 3.2645
# Epoch 4, step 4, loss = 2.9819
# Epoch 4, step 5, loss = 3.0498
# Epoch 4, step 6, loss = 2.9690
# Epoch 4, step 7, loss = 3.0037
# Epoch 4, step 8, loss = 2.7595
# Epoch 4, step 9, loss = 2.7596
# Epoch 4, step 10, loss = 2.7306
# Epoch 4, step 11, loss = 2.5990
# Epoch 4, step 12, loss = 2.7175
# Epoch 4, step 13, loss = 2.5204
# Epoch 4, step 14, loss = 0.4815
# Epoch 4, level1, accu = 0.9984, f1_score = 0.4996
# Epoch 4, level2, accu = 0.9916, f1_score = 0.9697
# Epoch 4, level3, accu = 0.9490, f1_score = 0.8715
# Epoch 4, level4, accu = 0.9412, f1_score = 0.7466
# ------------------------------------------------------------------
# Epoch 5, step 0, loss = 2.3548
# Epoch 5, step 1, loss = 2.0854
# Epoch 5, step 2, loss = 2.3574
# Epoch 5, step 3, loss = 2.3037
# Epoch 5, step 4, loss = 2.3414
# Epoch 5, step 5, loss = 1.9269
# Epoch 5, step 6, loss = 2.1485
# Epoch 5, step 7, loss = 2.1585
# Epoch 5, step 8, loss = 2.2584
# Epoch 5, step 9, loss = 1.6512
# Epoch 5, step 10, loss = 1.7920
# Epoch 5, step 11, loss = 1.8843
# Epoch 5, step 12, loss = 1.5613
# Epoch 5, step 13, loss = 1.7888
# Epoch 5, step 14, loss = 1.6423
# Epoch 5, level1, accu = 0.9994, f1_score = 0.8782
# Epoch 5, level2, accu = 0.9915, f1_score = 0.9612
# Epoch 5, level3, accu = 0.9649, f1_score = 0.8833
# Epoch 5, level4, accu = 0.9586, f1_score = 0.8308
# ------------------------------------------------------------------
# Epoch 6, step 0, loss = 1.5580
# Epoch 6, step 1, loss = 1.6475
# Epoch 6, step 2, loss = 1.6609
# Epoch 6, step 3, loss = 1.4402
# Epoch 6, step 4, loss = 1.5824
# Epoch 6, step 5, loss = 1.6629
# Epoch 6, step 6, loss = 1.5157
# Epoch 6, step 7, loss = 1.4837
# Epoch 6, step 8, loss = 1.5360
# Epoch 6, step 9, loss = 1.3889
# Epoch 6, step 10, loss = 1.4431
# Epoch 6, step 11, loss = 1.4732
# Epoch 6, step 12, loss = 1.1908
# Epoch 6, step 13, loss = 1.3417
# Epoch 6, step 14, loss = 3.9659
# Epoch 6, level1, accu = 0.9997, f1_score = 0.9523
# Epoch 6, level2, accu = 0.9934, f1_score = 0.9446
# Epoch 6, level3, accu = 0.9712, f1_score = 0.9089
# Epoch 6, level4, accu = 0.9718, f1_score = 0.9241
# ------------------------------------------------------------------
# Epoch 7, step 0, loss = 1.2613
# Epoch 7, step 1, loss = 1.1784
# Epoch 7, step 2, loss = 1.1631
# Epoch 7, step 3, loss = 1.1811
# Epoch 7, step 4, loss = 0.9935
# Epoch 7, step 5, loss = 1.2942
# Epoch 7, step 6, loss = 1.3080
# Epoch 7, step 7, loss = 1.2573
# Epoch 7, step 8, loss = 1.0652
# Epoch 7, step 9, loss = 1.1540
# Epoch 7, step 10, loss = 1.2057
# Epoch 7, step 11, loss = 0.9085
# Epoch 7, step 12, loss = 1.0867
# Epoch 7, step 13, loss = 1.1529
# Epoch 7, step 14, loss = 0.6145
# Epoch 7, level1, accu = 0.9997, f1_score = 0.9389
# Epoch 7, level2, accu = 0.9956, f1_score = 0.9812
# Epoch 7, level3, accu = 0.9773, f1_score = 0.9397
# Epoch 7, level4, accu = 0.9782, f1_score = 0.9551
# ------------------------------------------------------------------
# Epoch 8, step 0, loss = 1.0118
# Epoch 8, step 1, loss = 0.8786
# Epoch 8, step 2, loss = 0.9680
# Epoch 8, step 3, loss = 0.8518
# Epoch 8, step 4, loss = 0.9153
# Epoch 8, step 5, loss = 0.9374
# Epoch 8, step 6, loss = 0.9973
# Epoch 8, step 7, loss = 1.0050
# Epoch 8, step 8, loss = 0.8948
# Epoch 8, step 9, loss = 0.8836
# Epoch 8, step 10, loss = 0.8749
# Epoch 8, step 11, loss = 0.9954
# Epoch 8, step 12, loss = 0.8563
# Epoch 8, step 13, loss = 0.8699
# Epoch 8, step 14, loss = 0.2837
# Epoch 8, level1, accu = 0.9994, f1_score = 0.8946
# Epoch 8, level2, accu = 0.9953, f1_score = 0.9555
# Epoch 8, level3, accu = 0.9817, f1_score = 0.9611
# Epoch 8, level4, accu = 0.9828, f1_score = 0.9644
# ------------------------------------------------------------------
# Epoch 9, step 0, loss = 0.9913
# Epoch 9, step 1, loss = 0.8093
# Epoch 9, step 2, loss = 0.8066
# Epoch 9, step 3, loss = 0.7714
# Epoch 9, step 4, loss = 0.7600
# Epoch 9, step 5, loss = 0.6721
# Epoch 9, step 6, loss = 0.7851
# Epoch 9, step 7, loss = 0.9123
# Epoch 9, step 8, loss = 0.7345
# Epoch 9, step 9, loss = 0.8383
# Epoch 9, step 10, loss = 0.7093
# Epoch 9, step 11, loss = 0.6120
# Epoch 9, step 12, loss = 0.7123
# Epoch 9, step 13, loss = 0.6004
# Epoch 9, step 14, loss = 0.1312
# Epoch 9, level1, accu = 0.9996, f1_score = 0.9249
# Epoch 9, level2, accu = 0.9964, f1_score = 0.9819
# Epoch 9, level3, accu = 0.9850, f1_score = 0.9602
# Epoch 9, level4, accu = 0.9857, f1_score = 0.9739
# ------------------------------------------------------------------
# Epoch 10, step 0, loss = 0.6110
# Epoch 10, step 1, loss = 0.7434
# Epoch 10, step 2, loss = 0.6739
# Epoch 10, step 3, loss = 0.6363
# Epoch 10, step 4, loss = 0.5250
# Epoch 10, step 5, loss = 0.6013
# Epoch 10, step 6, loss = 0.7041
# Epoch 10, step 7, loss = 0.6293
# Epoch 10, step 8, loss = 0.6374
# Epoch 10, step 9, loss = 0.5297
# Epoch 10, step 10, loss = 0.7003
# Epoch 10, step 11, loss = 0.6014
# Epoch 10, step 12, loss = 0.6101
# Epoch 10, step 13, loss = 0.6670
# Epoch 10, step 14, loss = 0.2752
# Epoch 10, level1, accu = 0.9996, f1_score = 0.9249
# Epoch 10, level2, accu = 0.9969, f1_score = 0.9900
# Epoch 10, level3, accu = 0.9875, f1_score = 0.9611
# Epoch 10, level4, accu = 0.9886, f1_score = 0.9792
# ------------------------------------------------------------------
# Epoch 11, step 0, loss = 0.4945
# Epoch 11, step 1, loss = 0.5253
# Epoch 11, step 2, loss = 0.5110
# Epoch 11, step 3, loss = 0.5495
# Epoch 11, step 4, loss = 0.4577
# Epoch 11, step 5, loss = 0.6546
# Epoch 11, step 6, loss = 0.4919
# Epoch 11, step 7, loss = 0.5207
# Epoch 11, step 8, loss = 0.4969
# Epoch 11, step 9, loss = 0.5833
# Epoch 11, step 10, loss = 0.5255
# Epoch 11, step 11, loss = 0.5365
# Epoch 11, step 12, loss = 0.5200
# Epoch 11, step 13, loss = 0.5514
# Epoch 11, step 14, loss = 0.9853
# Epoch 11, level1, accu = 0.9999, f1_score = 0.9772
# Epoch 11, level2, accu = 0.9974, f1_score = 0.9905
# Epoch 11, level3, accu = 0.9887, f1_score = 0.9747
# Epoch 11, level4, accu = 0.9913, f1_score = 0.9840
# ------------------------------------------------------------------
# Epoch 12, step 0, loss = 0.5233
# Epoch 12, step 1, loss = 0.5808
# Epoch 12, step 2, loss = 0.4583
# Epoch 12, step 3, loss = 0.4580
# Epoch 12, step 4, loss = 0.4260
# Epoch 12, step 5, loss = 0.4049
# Epoch 12, step 6, loss = 0.4522
# Epoch 12, step 7, loss = 0.4324
# Epoch 12, step 8, loss = 0.5294
# Epoch 12, step 9, loss = 0.3932
# Epoch 12, step 10, loss = 0.4094
# Epoch 12, step 11, loss = 0.4651
# Epoch 12, step 12, loss = 0.4371
# Epoch 12, step 13, loss = 0.4665
# Epoch 12, step 14, loss = 0.0744
# Epoch 12, level1, accu = 0.9995, f1_score = 0.9101
# Epoch 12, level2, accu = 0.9976, f1_score = 0.9829
# Epoch 12, level3, accu = 0.9902, f1_score = 0.9748
# Epoch 12, level4, accu = 0.9922, f1_score = 0.9861
# ------------------------------------------------------------------
# Epoch 13, step 0, loss = 0.3885
# Epoch 13, step 1, loss = 0.3827
# Epoch 13, step 2, loss = 0.3650
# Epoch 13, step 3, loss = 0.3209
# Epoch 13, step 4, loss = 0.4220
# Epoch 13, step 5, loss = 0.4164
# Epoch 13, step 6, loss = 0.3869
# Epoch 13, step 7, loss = 0.3925
# Epoch 13, step 8, loss = 0.3800
# Epoch 13, step 9, loss = 0.3626
# Epoch 13, step 10, loss = 0.3006
# Epoch 13, step 11, loss = 0.3852
# Epoch 13, step 12, loss = 0.4054
# Epoch 13, step 13, loss = 0.4268
# Epoch 13, step 14, loss = 0.2734
# Epoch 13, level1, accu = 0.9999, f1_score = 0.9889
# Epoch 13, level2, accu = 0.9981, f1_score = 0.9910
# Epoch 13, level3, accu = 0.9925, f1_score = 0.9813
# Epoch 13, level4, accu = 0.9951, f1_score = 0.9926
# ------------------------------------------------------------------
# Epoch 14, step 0, loss = 0.3752
# Epoch 14, step 1, loss = 0.3629
# Epoch 14, step 2, loss = 0.3028
# Epoch 14, step 3, loss = 0.4084
# Epoch 14, step 4, loss = 0.3241
# Epoch 14, step 5, loss = 0.3459
# Epoch 14, step 6, loss = 0.3383
# Epoch 14, step 7, loss = 0.3482
# Epoch 14, step 8, loss = 0.2957
# Epoch 14, step 9, loss = 0.3330
# Epoch 14, step 10, loss = 0.2794
# Epoch 14, step 11, loss = 0.3315
# Epoch 14, step 12, loss = 0.3019
# Epoch 14, step 13, loss = 0.2689
# Epoch 14, step 14, loss = 0.0785
# Epoch 14, level1, accu = 0.9998, f1_score = 0.9651
# Epoch 14, level2, accu = 0.9982, f1_score = 0.9834
# Epoch 14, level3, accu = 0.9940, f1_score = 0.9886
# Epoch 14, level4, accu = 0.9963, f1_score = 0.9947
# ------------------------------------------------------------------
# Epoch 15, step 0, loss = 0.2692
# Epoch 15, step 1, loss = 0.2472
# Epoch 15, step 2, loss = 0.2823
# Epoch 15, step 3, loss = 0.2858
# Epoch 15, step 4, loss = 0.2713
# Epoch 15, step 5, loss = 0.2484
# Epoch 15, step 6, loss = 0.2636
# Epoch 15, step 7, loss = 0.3404
# Epoch 15, step 8, loss = 0.2698
# Epoch 15, step 9, loss = 0.2488
# Epoch 15, step 10, loss = 0.2558
# Epoch 15, step 11, loss = 0.2672
# Epoch 15, step 12, loss = 0.2867
# Epoch 15, step 13, loss = 0.3238
# Epoch 15, step 14, loss = 0.1618
# Epoch 15, level1, accu = 0.9998, f1_score = 0.9651
# Epoch 15, level2, accu = 0.9984, f1_score = 0.9755
# Epoch 15, level3, accu = 0.9950, f1_score = 0.9916
# Epoch 15, level4, accu = 0.9976, f1_score = 0.9958
# ------------------------------------------------------------------
# Epoch 16, step 0, loss = 0.2883
# Epoch 16, step 1, loss = 0.2078
# Epoch 16, step 2, loss = 0.2169
# Epoch 16, step 3, loss = 0.3070
# Epoch 16, step 4, loss = 0.2459
# Epoch 16, step 5, loss = 0.2500
# Epoch 16, step 6, loss = 0.1917
# Epoch 16, step 7, loss = 0.2361
# Epoch 16, step 8, loss = 0.2441
# Epoch 16, step 9, loss = 0.2278
# Epoch 16, step 10, loss = 0.2558
# Epoch 16, step 11, loss = 0.2019
# Epoch 16, step 12, loss = 0.1913
# Epoch 16, step 13, loss = 0.2020
# Epoch 16, step 14, loss = 0.3171
# Epoch 16, level1, accu = 0.9997, f1_score = 0.9523
# Epoch 16, level2, accu = 0.9986, f1_score = 0.9837
# Epoch 16, level3, accu = 0.9969, f1_score = 0.9931
# Epoch 16, level4, accu = 0.9983, f1_score = 0.9979
# ------------------------------------------------------------------
# Epoch 17, step 0, loss = 0.2201
# Epoch 17, step 1, loss = 0.2170
# Epoch 17, step 2, loss = 0.1935
# Epoch 17, step 3, loss = 0.2145
# Epoch 17, step 4, loss = 0.2108
# Epoch 17, step 5, loss = 0.2188
# Epoch 17, step 6, loss = 0.1913
# Epoch 17, step 7, loss = 0.2195
# Epoch 17, step 8, loss = 0.1655
# Epoch 17, step 9, loss = 0.2079
# Epoch 17, step 10, loss = 0.2080
# Epoch 17, step 11, loss = 0.1869
# Epoch 17, step 12, loss = 0.1926
# Epoch 17, step 13, loss = 0.2204
# Epoch 17, step 14, loss = 0.0473
# Epoch 17, level1, accu = 0.9999, f1_score = 0.9772
# Epoch 17, level2, accu = 0.9990, f1_score = 0.9917
# Epoch 17, level3, accu = 0.9973, f1_score = 0.9956
# Epoch 17, level4, accu = 0.9989, f1_score = 0.9991
# ------------------------------------------------------------------
# Epoch 18, step 0, loss = 0.1928
# Epoch 18, step 1, loss = 0.1579
# Epoch 18, step 2, loss = 0.1823
# Epoch 18, step 3, loss = 0.1436
# Epoch 18, step 4, loss = 0.1750
# Epoch 18, step 5, loss = 0.2042
# Epoch 18, step 6, loss = 0.1925
# Epoch 18, step 7, loss = 0.2092
# Epoch 18, step 8, loss = 0.1376
# Epoch 18, step 9, loss = 0.1610
# Epoch 18, step 10, loss = 0.1646
# Epoch 18, step 11, loss = 0.1913
# Epoch 18, step 12, loss = 0.1733
# Epoch 18, step 13, loss = 0.1541
# Epoch 18, step 14, loss = 0.5295
# Epoch 18, level1, accu = 0.9998, f1_score = 0.9651
# Epoch 18, level2, accu = 0.9992, f1_score = 0.9920
# Epoch 18, level3, accu = 0.9983, f1_score = 0.9965
# Epoch 18, level4, accu = 0.9994, f1_score = 0.9995
# ------------------------------------------------------------------
# Epoch 19, step 0, loss = 0.1338
# Epoch 19, step 1, loss = 0.2014
# Epoch 19, step 2, loss = 0.1874
# Epoch 19, step 3, loss = 0.2027
# Epoch 19, step 4, loss = 0.2446
# Epoch 19, step 5, loss = 0.1684
# Epoch 19, step 6, loss = 0.2530
# Epoch 19, step 7, loss = 0.1986
# Epoch 19, step 8, loss = 0.1525
# Epoch 19, step 9, loss = 0.1508
# Epoch 19, step 10, loss = 0.1526
# Epoch 19, step 11, loss = 0.1418
# Epoch 19, step 12, loss = 0.1272
# Epoch 19, step 13, loss = 0.1496
# Epoch 19, step 14, loss = 0.0136
# Epoch 19, level1, accu = 0.9999, f1_score = 0.9889
# Epoch 19, level2, accu = 0.9992, f1_score = 0.9920
# Epoch 19, level3, accu = 0.9980, f1_score = 0.9941
# Epoch 19, level4, accu = 0.9994, f1_score = 0.9995
# ------------------------------------------------------------------
# Epoch 20, step 0, loss = 0.1550
# Epoch 20, step 1, loss = 0.1391
# Epoch 20, step 2, loss = 0.1614
# Epoch 20, step 3, loss = 0.1484
# Epoch 20, step 4, loss = 0.1451
# Epoch 20, step 5, loss = 0.1136
# Epoch 20, step 6, loss = 0.1730
# Epoch 20, step 7, loss = 0.1512
# Epoch 20, step 8, loss = 0.1400
# Epoch 20, step 9, loss = 0.1357
# Epoch 20, step 10, loss = 0.2043
# Epoch 20, step 11, loss = 0.1273
# Epoch 20, step 12, loss = 0.1339
# Epoch 20, step 13, loss = 0.1109
# Epoch 20, step 14, loss = 0.1111
# Epoch 20, level1, accu = 0.9998, f1_score = 0.9651
# Epoch 20, level2, accu = 0.9991, f1_score = 0.9992
# Epoch 20, level3, accu = 0.9990, f1_score = 0.9991
# Epoch 20, level4, accu = 0.9994, f1_score = 0.9995
# ------------------------------------------------------------------
# Epoch 21, step 0, loss = 0.1518
# Epoch 21, step 1, loss = 0.1246
# Epoch 21, step 2, loss = 0.1167
# Epoch 21, step 3, loss = 0.1570
# Epoch 21, step 4, loss = 0.1149
# Epoch 21, step 5, loss = 0.1036
# Epoch 21, step 6, loss = 0.1292
# Epoch 21, step 7, loss = 0.1060
# Epoch 21, step 8, loss = 0.1115
# Epoch 21, step 9, loss = 0.1054
# Epoch 21, step 10, loss = 0.1035
# Epoch 21, step 11, loss = 0.1149
# Epoch 21, step 12, loss = 0.1402
# Epoch 21, step 13, loss = 0.0984
# Epoch 21, step 14, loss = 0.0932
# Epoch 21, level1, accu = 0.9999, f1_score = 0.9889
# Epoch 21, level2, accu = 0.9996, f1_score = 0.9996
# Epoch 21, level3, accu = 0.9992, f1_score = 0.9994
# Epoch 21, level4, accu = 0.9997, f1_score = 0.9998
# ------------------------------------------------------------------
# Epoch 22, step 0, loss = 0.1103
# Epoch 22, step 1, loss = 0.1239
# Epoch 22, step 2, loss = 0.1146
# Epoch 22, step 3, loss = 0.1652
# Epoch 22, step 4, loss = 0.1228
# Epoch 22, step 5, loss = 0.1028
# Epoch 22, step 6, loss = 0.1050
# Epoch 22, step 7, loss = 0.0874
# Epoch 22, step 8, loss = 0.1195
# Epoch 22, step 9, loss = 0.0879
# Epoch 22, step 10, loss = 0.1013
# Epoch 22, step 11, loss = 0.0949
# Epoch 22, step 12, loss = 0.2128
# Epoch 22, step 13, loss = 0.0909
# Epoch 22, step 14, loss = 0.1072
# Epoch 22, level1, accu = 0.9999, f1_score = 0.9772
# Epoch 22, level2, accu = 0.9999, f1_score = 0.9999
# Epoch 22, level3, accu = 0.9994, f1_score = 0.9995
# Epoch 22, level4, accu = 0.9996, f1_score = 0.9996
# ------------------------------------------------------------------
# Epoch 23, step 0, loss = 0.0917
# Epoch 23, step 1, loss = 0.1105
# Epoch 23, step 2, loss = 0.0986
# Epoch 23, step 3, loss = 0.0788
# Epoch 23, step 4, loss = 0.0927
# Epoch 23, step 5, loss = 0.1017
# Epoch 23, step 6, loss = 0.0964
# Epoch 23, step 7, loss = 0.0810
# Epoch 23, step 8, loss = 0.0909
# Epoch 23, step 9, loss = 0.0818
# Epoch 23, step 10, loss = 0.0963
# Epoch 23, step 11, loss = 0.0789
# Epoch 23, step 12, loss = 0.1047
# Epoch 23, step 13, loss = 0.0792
# Epoch 23, step 14, loss = 0.1402
# Epoch 23, level1, accu = 0.9999, f1_score = 0.9889
# Epoch 23, level2, accu = 0.9997, f1_score = 0.9998
# Epoch 23, level3, accu = 0.9995, f1_score = 0.9996
# Epoch 23, level4, accu = 0.9999, f1_score = 0.9999
# ------------------------------------------------------------------
# Epoch 24, step 0, loss = 0.0870
# Epoch 24, step 1, loss = 0.0850
# Epoch 24, step 2, loss = 0.0951
# Epoch 24, step 3, loss = 0.0873
# Epoch 24, step 4, loss = 0.0719
# Epoch 24, step 5, loss = 0.0910
# Epoch 24, step 6, loss = 0.0803
# Epoch 24, step 7, loss = 0.0804
# Epoch 24, step 8, loss = 0.0764
# Epoch 24, step 9, loss = 0.1007
# Epoch 24, step 10, loss = 0.0666
# Epoch 24, step 11, loss = 0.0756
# Epoch 24, step 12, loss = 0.0824
# Epoch 24, step 13, loss = 0.0751
# Epoch 24, step 14, loss = 0.0165
# Epoch 24, level1, accu = 0.9999, f1_score = 0.9889
# Epoch 24, level2, accu = 0.9997, f1_score = 0.9998
# Epoch 24, level3, accu = 0.9998, f1_score = 0.9998
# Epoch 24, level4, accu = 0.9999, f1_score = 0.9999
# ------------------------------------------------------------------
# Epoch 25, step 0, loss = 0.0737
# Epoch 25, step 1, loss = 0.0720
# Epoch 25, step 2, loss = 0.1189
# Epoch 25, step 3, loss = 0.0768
# Epoch 25, step 4, loss = 0.0621
# Epoch 25, step 5, loss = 0.0785
# Epoch 25, step 6, loss = 0.0696
# Epoch 25, step 7, loss = 0.1164
# Epoch 25, step 8, loss = 0.0609
# Epoch 25, step 9, loss = 0.0603
# Epoch 25, step 10, loss = 0.0810
# Epoch 25, step 11, loss = 0.0806
# Epoch 25, step 12, loss = 0.0888
# Epoch 25, step 13, loss = 0.0786
# Epoch 25, step 14, loss = 0.0403
# Epoch 25, level1, accu = 0.9999, f1_score = 0.9772
# Epoch 25, level2, accu = 0.9999, f1_score = 0.9999
# Epoch 25, level3, accu = 0.9998, f1_score = 0.9998
# Epoch 25, level4, accu = 0.9999, f1_score = 0.9999
# ------------------------------------------------------------------
# Epoch 26, step 0, loss = 0.0721
# Epoch 26, step 1, loss = 0.0574
# Epoch 26, step 2, loss = 0.0805
# Epoch 26, step 3, loss = 0.0675
# Epoch 26, step 4, loss = 0.0699
# Epoch 26, step 5, loss = 0.0668
# Epoch 26, step 6, loss = 0.0671
# Epoch 26, step 7, loss = 0.0569
# Epoch 26, step 8, loss = 0.0499
# Epoch 26, step 9, loss = 0.0538
# Epoch 26, step 10, loss = 0.0633
# Epoch 26, step 11, loss = 0.0591
# Epoch 26, step 12, loss = 0.0806
# Epoch 26, step 13, loss = 0.0834
# Epoch 26, step 14, loss = 0.0082
# Epoch 26, level1, accu = 0.9998, f1_score = 0.9651
# Epoch 26, level2, accu = 0.9999, f1_score = 0.9999
# Epoch 26, level3, accu = 0.9999, f1_score = 0.9999
# Epoch 26, level4, accu = 0.9999, f1_score = 0.9999
# ------------------------------------------------------------------
# Epoch 27, step 0, loss = 0.0550
# Epoch 27, step 1, loss = 0.0591
# Epoch 27, step 2, loss = 0.0554
# Epoch 27, step 3, loss = 0.0600
# Epoch 27, step 4, loss = 0.0512
# Epoch 27, step 5, loss = 0.0576
# Epoch 27, step 6, loss = 0.0930
# Epoch 27, step 7, loss = 0.0535
# Epoch 27, step 8, loss = 0.0672
# Epoch 27, step 9, loss = 0.0582
# Epoch 27, step 10, loss = 0.0525
# Epoch 27, step 11, loss = 0.0664
# Epoch 27, step 12, loss = 0.0660
# Epoch 27, step 13, loss = 0.0500
# Epoch 27, step 14, loss = 0.0350
# Epoch 27, level1, accu = 0.9999, f1_score = 0.9772
# Epoch 27, level2, accu = 0.9999, f1_score = 0.9999
# Epoch 27, level3, accu = 0.9999, f1_score = 0.9999
# Epoch 27, level4, accu = 0.9999, f1_score = 0.9999
# ------------------------------------------------------------------
# Epoch 28, step 0, loss = 0.0498
# Epoch 28, step 1, loss = 0.0570
# Epoch 28, step 2, loss = 0.0521
# Epoch 28, step 3, loss = 0.0567
# Epoch 28, step 4, loss = 0.0608
# Epoch 28, step 5, loss = 0.0608
# Epoch 28, step 6, loss = 0.0558
# Epoch 28, step 7, loss = 0.0531
# Epoch 28, step 8, loss = 0.0544
# Epoch 28, step 9, loss = 0.0511
# Epoch 28, step 10, loss = 0.0472
# Epoch 28, step 11, loss = 0.0531
# Epoch 28, step 12, loss = 0.0526
# Epoch 28, step 13, loss = 0.0510
# Epoch 28, step 14, loss = 0.0817
# Epoch 28, level1, accu = 0.9999, f1_score = 0.9889
# Epoch 28, level2, accu = 0.9999, f1_score = 0.9999
# Epoch 28, level3, accu = 1.0000, f1_score = 1.0000
# Epoch 28, level4, accu = 1.0000, f1_score = 1.0000
# ------------------------------------------------------------------
# Epoch 29, step 0, loss = 0.0529
# Epoch 29, step 1, loss = 0.0465
# Epoch 29, step 2, loss = 0.0450
# Epoch 29, step 3, loss = 0.1246
# Epoch 29, step 4, loss = 0.0513
# Epoch 29, step 5, loss = 0.0517
# Epoch 29, step 6, loss = 0.0518
# Epoch 29, step 7, loss = 0.0472
# Epoch 29, step 8, loss = 0.0466
# Epoch 29, step 9, loss = 0.0639
# Epoch 29, step 10, loss = 0.0471
# Epoch 29, step 11, loss = 0.0490
# Epoch 29, step 12, loss = 0.0512
# Epoch 29, step 13, loss = 0.0515
# Epoch 29, step 14, loss = 0.0587
# Epoch 29, level1, accu = 0.9999, f1_score = 0.9772
# Epoch 29, level2, accu = 0.9999, f1_score = 0.9999
# Epoch 29, level3, accu = 0.9999, f1_score = 0.9999
# Epoch 29, level4, accu = 0.9999, f1_score = 0.9999
# ------------------------------------------------------------------
# Epoch 30, step 0, loss = 0.0457
# Epoch 30, step 1, loss = 0.0542
# Epoch 30, step 2, loss = 0.0498
# Epoch 30, step 3, loss = 0.0426
# Epoch 30, step 4, loss = 0.0452
# Epoch 30, step 5, loss = 0.0425
# Epoch 30, step 6, loss = 0.0485
# Epoch 30, step 7, loss = 0.0580
# Epoch 30, step 8, loss = 0.0391
# Epoch 30, step 9, loss = 0.0455
# Epoch 30, step 10, loss = 0.0494
# Epoch 30, step 11, loss = 0.0426
# Epoch 30, step 12, loss = 0.0424
# Epoch 30, step 13, loss = 0.0461
# Epoch 30, step 14, loss = 0.0381
# Epoch 30, level1, accu = 0.9999, f1_score = 0.9772
# Epoch 30, level2, accu = 0.9999, f1_score = 0.9999
# Epoch 30, level3, accu = 0.9999, f1_score = 0.9999
# Epoch 30, level4, accu = 0.9999, f1_score = 0.9999
# ------------------------------------------------------------------
# Epoch 31, step 0, loss = 0.0466
# Epoch 31, step 1, loss = 0.0436
# Epoch 31, step 2, loss = 0.0431
# Epoch 31, step 3, loss = 0.0457
# Epoch 31, step 4, loss = 0.0419
# Epoch 31, step 5, loss = 0.0466
# Epoch 31, step 6, loss = 0.0357
# Epoch 31, step 7, loss = 0.0367
# Epoch 31, step 8, loss = 0.0377
# Epoch 31, step 9, loss = 0.0499
# Epoch 31, step 10, loss = 0.0397
# Epoch 31, step 11, loss = 0.0473
# Epoch 31, step 12, loss = 0.0359
# Epoch 31, step 13, loss = 0.0358
# Epoch 31, step 14, loss = 0.0763
# Epoch 31, level1, accu = 1.0000, f1_score = 1.0000
# Epoch 31, level2, accu = 0.9999, f1_score = 0.9999
# Epoch 31, level3, accu = 0.9999, f1_score = 0.9999
# Epoch 31, level4, accu = 0.9999, f1_score = 0.9999
# ------------------------------------------------------------------
# Epoch 32, step 0, loss = 0.0419
# Epoch 32, step 1, loss = 0.0449
# Epoch 32, step 2, loss = 0.0377
# Epoch 32, step 3, loss = 0.0428
# Epoch 32, step 4, loss = 0.0378
# Epoch 32, step 5, loss = 0.0406
# Epoch 32, step 6, loss = 0.0382
# Epoch 32, step 7, loss = 0.0349
# Epoch 32, step 8, loss = 0.0427
# Epoch 32, step 9, loss = 0.0368
# Epoch 32, step 10, loss = 0.0363
# Epoch 32, step 11, loss = 0.0336
# Epoch 32, step 12, loss = 0.0413
# Epoch 32, step 13, loss = 0.1186
# Epoch 32, step 14, loss = 0.1557
# Epoch 32, level1, accu = 0.9999, f1_score = 0.9889
# Epoch 32, level2, accu = 0.9999, f1_score = 0.9999
# Epoch 32, level3, accu = 0.9999, f1_score = 0.9999
# Epoch 32, level4, accu = 0.9999, f1_score = 0.9999
# ------------------------------------------------------------------
# Epoch 33, step 0, loss = 0.0387
# Epoch 33, step 1, loss = 0.0625
# Epoch 33, step 2, loss = 0.0610
# Epoch 33, step 3, loss = 0.0673
# Epoch 33, step 4, loss = 0.0601
# Epoch 33, step 5, loss = 0.0419
# Epoch 33, step 6, loss = 0.0445
# Epoch 33, step 7, loss = 0.0413
# Epoch 33, step 8, loss = 0.0364
# Epoch 33, step 9, loss = 0.0307
# Epoch 33, step 10, loss = 0.0371
# Epoch 33, step 11, loss = 0.0433
# Epoch 33, step 12, loss = 0.0602
# Epoch 33, step 13, loss = 0.0371
# Epoch 33, step 14, loss = 0.0053
# Epoch 33, level1, accu = 0.9999, f1_score = 0.9889
# Epoch 33, level2, accu = 1.0000, f1_score = 1.0000
# Epoch 33, level3, accu = 0.9999, f1_score = 0.9999
# Epoch 33, level4, accu = 0.9999, f1_score = 0.9999
# ------------------------------------------------------------------
# Epoch 34, step 0, loss = 0.0323
# Epoch 34, step 1, loss = 0.0372
# Epoch 34, step 2, loss = 0.0421
# Epoch 34, step 3, loss = 0.0317
# Epoch 34, step 4, loss = 0.0300
# Epoch 34, step 5, loss = 0.0301
# Epoch 34, step 6, loss = 0.0282
# Epoch 34, step 7, loss = 0.0364
# Epoch 34, step 8, loss = 0.0342
# Epoch 34, step 9, loss = 0.0302
# Epoch 34, step 10, loss = 0.0323
# Epoch 34, step 11, loss = 0.0374
# Epoch 34, step 12, loss = 0.0345
# Epoch 34, step 13, loss = 0.0295
# Epoch 34, step 14, loss = 0.0040
# Epoch 34, level1, accu = 1.0000, f1_score = 1.0000
# Epoch 34, level2, accu = 1.0000, f1_score = 1.0000
# Epoch 34, level3, accu = 1.0000, f1_score = 1.0000
# Epoch 34, level4, accu = 1.0000, f1_score = 1.0000
# ------------------------------------------------------------------
# Epoch 35, step 0, loss = 0.0312
# Epoch 35, step 1, loss = 0.0264
# Epoch 35, step 2, loss = 0.1727
# Epoch 35, step 3, loss = 0.0299
# Epoch 35, step 4, loss = 0.0323
# Epoch 35, step 5, loss = 0.0276
# Epoch 35, step 6, loss = 0.0323
# Epoch 35, step 7, loss = 0.0308
# Epoch 35, step 8, loss = 0.0417
# Epoch 35, step 9, loss = 0.0310
# Epoch 35, step 10, loss = 0.0319
# Epoch 35, step 11, loss = 0.0328
# Epoch 35, step 12, loss = 0.0290
# Epoch 35, step 13, loss = 0.0299
# Epoch 35, step 14, loss = 0.0651
# Epoch 35, level1, accu = 1.0000, f1_score = 1.0000
# Epoch 35, level2, accu = 1.0000, f1_score = 1.0000
# Epoch 35, level3, accu = 0.9999, f1_score = 0.9999
# Epoch 35, level4, accu = 0.9999, f1_score = 0.9999
# ------------------------------------------------------------------
# Epoch 36, step 0, loss = 0.0301
# Epoch 36, step 1, loss = 0.0326
# Epoch 36, step 2, loss = 0.0373
# Epoch 36, step 3, loss = 0.0275
# Epoch 36, step 4, loss = 0.0284
# Epoch 36, step 5, loss = 0.0299
# Epoch 36, step 6, loss = 0.0317
# Epoch 36, step 7, loss = 0.0233
# Epoch 36, step 8, loss = 0.0281
# Epoch 36, step 9, loss = 0.1075
# Epoch 36, step 10, loss = 0.0271
# Epoch 36, step 11, loss = 0.0310
# Epoch 36, step 12, loss = 0.0283
# Epoch 36, step 13, loss = 0.0377
# Epoch 36, step 14, loss = 0.0037
# Epoch 36, level1, accu = 1.0000, f1_score = 1.0000
# Epoch 36, level2, accu = 0.9999, f1_score = 0.9999
# Epoch 36, level3, accu = 0.9999, f1_score = 0.9999
# Epoch 36, level4, accu = 0.9999, f1_score = 0.9999
# ------------------------------------------------------------------
# Epoch 37, step 0, loss = 0.0413
# Epoch 37, step 1, loss = 0.0461
# Epoch 37, step 2, loss = 0.0421
# Epoch 37, step 3, loss = 0.0315
# Epoch 37, step 4, loss = 0.0298
# Epoch 37, step 5, loss = 0.0941
# Epoch 37, step 6, loss = 0.0257
# Epoch 37, step 7, loss = 0.0249
# Epoch 37, step 8, loss = 0.0298
# Epoch 37, step 9, loss = 0.0279
# Epoch 37, step 10, loss = 0.0427
# Epoch 37, step 11, loss = 0.0411
# Epoch 37, step 12, loss = 0.0327
# Epoch 37, step 13, loss = 0.0300
# Epoch 37, step 14, loss = 0.0149
# Epoch 37, level1, accu = 1.0000, f1_score = 1.0000
# Epoch 37, level2, accu = 1.0000, f1_score = 1.0000
# Epoch 37, level3, accu = 0.9999, f1_score = 0.9999
# Epoch 37, level4, accu = 0.9999, f1_score = 0.9999
# ------------------------------------------------------------------
# Epoch 38, step 0, loss = 0.0262
# Epoch 38, step 1, loss = 0.0222
# Epoch 38, step 2, loss = 0.0306
# Epoch 38, step 3, loss = 0.0268
# Epoch 38, step 4, loss = 0.0281
# Epoch 38, step 5, loss = 0.0200
# Epoch 38, step 6, loss = 0.0267
# Epoch 38, step 7, loss = 0.0246
# Epoch 38, step 8, loss = 0.0279
# Epoch 38, step 9, loss = 0.0389
# Epoch 38, step 10, loss = 0.0238
# Epoch 38, step 11, loss = 0.0277
# Epoch 38, step 12, loss = 0.0250
# Epoch 38, step 13, loss = 0.0234
# Epoch 38, step 14, loss = 0.0017
# Epoch 38, level1, accu = 1.0000, f1_score = 1.0000
# Epoch 38, level2, accu = 1.0000, f1_score = 1.0000
# Epoch 38, level3, accu = 0.9999, f1_score = 0.9999
# Epoch 38, level4, accu = 0.9999, f1_score = 0.9999
# ------------------------------------------------------------------
# Epoch 39, step 0, loss = 0.0230
# Epoch 39, step 1, loss = 0.0208
# Epoch 39, step 2, loss = 0.0217
# Epoch 39, step 3, loss = 0.1178
# Epoch 39, step 4, loss = 0.0220
# Epoch 39, step 5, loss = 0.0256
# Epoch 39, step 6, loss = 0.0234
# Epoch 39, step 7, loss = 0.0279
# Epoch 39, step 8, loss = 0.0284
# Epoch 39, step 9, loss = 0.0283
# Epoch 39, step 10, loss = 0.0268
# Epoch 39, step 11, loss = 0.0187
# Epoch 39, step 12, loss = 0.0269
# Epoch 39, step 13, loss = 0.0225
# Epoch 39, step 14, loss = 0.0085
# Epoch 39, level1, accu = 1.0000, f1_score = 1.0000
# Epoch 39, level2, accu = 1.0000, f1_score = 1.0000
# Epoch 39, level3, accu = 0.9999, f1_score = 0.9999
# Epoch 39, level4, accu = 0.9999, f1_score = 0.9999
# ------------------------------------------------------------------
# Epoch 40, step 0, loss = 0.0238
# Epoch 40, step 1, loss = 0.0208
# Epoch 40, step 2, loss = 0.0248
# Epoch 40, step 3, loss = 0.0233
# Epoch 40, step 4, loss = 0.0243
# Epoch 40, step 5, loss = 0.0197
# Epoch 40, step 6, loss = 0.0234
# Epoch 40, step 7, loss = 0.0221
# Epoch 40, step 8, loss = 0.0227
# Epoch 40, step 9, loss = 0.0172
# Epoch 40, step 10, loss = 0.0215
# Epoch 40, step 11, loss = 0.0200
# Epoch 40, step 12, loss = 0.0168
# Epoch 40, step 13, loss = 0.0186
# Epoch 40, step 14, loss = 0.0682
# Epoch 40, level1, accu = 1.0000, f1_score = 1.0000
# Epoch 40, level2, accu = 1.0000, f1_score = 1.0000
# Epoch 40, level3, accu = 1.0000, f1_score = 1.0000
# Epoch 40, level4, accu = 1.0000, f1_score = 1.0000
# ------------------------------------------------------------------
# Epoch 41, step 0, loss = 0.0195
# Epoch 41, step 1, loss = 0.0167
# Epoch 41, step 2, loss = 0.0206
# Epoch 41, step 3, loss = 0.0189
# Epoch 41, step 4, loss = 0.0298
# Epoch 41, step 5, loss = 0.0239
# Epoch 41, step 6, loss = 0.0221
# Epoch 41, step 7, loss = 0.0227
# Epoch 41, step 8, loss = 0.0222
# Epoch 41, step 9, loss = 0.0303
# Epoch 41, step 10, loss = 0.0198
# Epoch 41, step 11, loss = 0.0222
# Epoch 41, step 12, loss = 0.0175
# Epoch 41, step 13, loss = 0.0229
# Epoch 41, step 14, loss = 0.0079
# Epoch 41, level1, accu = 1.0000, f1_score = 1.0000
# Epoch 41, level2, accu = 1.0000, f1_score = 1.0000
# Epoch 41, level3, accu = 1.0000, f1_score = 1.0000
# Epoch 41, level4, accu = 1.0000, f1_score = 1.0000
# ------------------------------------------------------------------
# Epoch 42, step 0, loss = 0.0185
# Epoch 42, step 1, loss = 0.0185
# Epoch 42, step 2, loss = 0.0188
# Epoch 42, step 3, loss = 0.0202
# Epoch 42, step 4, loss = 0.0244
# Epoch 42, step 5, loss = 0.0189
# Epoch 42, step 6, loss = 0.0181
# Epoch 42, step 7, loss = 0.0191
# Epoch 42, step 8, loss = 0.0178
# Epoch 42, step 9, loss = 0.0174
# Epoch 42, step 10, loss = 0.0180
# Epoch 42, step 11, loss = 0.0182
# Epoch 42, step 12, loss = 0.0186
# Epoch 42, step 13, loss = 0.0184
# Epoch 42, step 14, loss = 0.0273
# Epoch 42, level1, accu = 1.0000, f1_score = 1.0000
# Epoch 42, level2, accu = 1.0000, f1_score = 1.0000
# Epoch 42, level3, accu = 1.0000, f1_score = 1.0000
# Epoch 42, level4, accu = 1.0000, f1_score = 1.0000
# ------------------------------------------------------------------
# Epoch 43, step 0, loss = 0.0183
# Epoch 43, step 1, loss = 0.0176
# Epoch 43, step 2, loss = 0.0177
# Epoch 43, step 3, loss = 0.0178
# Epoch 43, step 4, loss = 0.0179
# Epoch 43, step 5, loss = 0.0173
# Epoch 43, step 6, loss = 0.0187
# Epoch 43, step 7, loss = 0.0145
# Epoch 43, step 8, loss = 0.0170
# Epoch 43, step 9, loss = 0.0201
# Epoch 43, step 10, loss = 0.0222
# Epoch 43, step 11, loss = 0.0185
# Epoch 43, step 12, loss = 0.0139
# Epoch 43, step 13, loss = 0.0178
# Epoch 43, step 14, loss = 0.0053
# Epoch 43, level1, accu = 1.0000, f1_score = 1.0000
# Epoch 43, level2, accu = 1.0000, f1_score = 1.0000
# Epoch 43, level3, accu = 1.0000, f1_score = 1.0000
# Epoch 43, level4, accu = 1.0000, f1_score = 1.0000
# ------------------------------------------------------------------
# Epoch 44, step 0, loss = 0.0141
# Epoch 44, step 1, loss = 0.0197
# Epoch 44, step 2, loss = 0.0147
# Epoch 44, step 3, loss = 0.0152
# Epoch 44, step 4, loss = 0.0208
# Epoch 44, step 5, loss = 0.0192
# Epoch 44, step 6, loss = 0.0187
# Epoch 44, step 7, loss = 0.0169
# Epoch 44, step 8, loss = 0.0141
# Epoch 44, step 9, loss = 0.0159
# Epoch 44, step 10, loss = 0.0170
# Epoch 44, step 11, loss = 0.0138
# Epoch 44, step 12, loss = 0.0171
# Epoch 44, step 13, loss = 0.0159
# Epoch 44, step 14, loss = 0.0188
# Epoch 44, level1, accu = 1.0000, f1_score = 1.0000
# Epoch 44, level2, accu = 1.0000, f1_score = 1.0000
# Epoch 44, level3, accu = 1.0000, f1_score = 1.0000
# Epoch 44, level4, accu = 1.0000, f1_score = 1.0000
# ------------------------------------------------------------------
# Epoch 45, step 0, loss = 0.0158
# Epoch 45, step 1, loss = 0.0337
# Epoch 45, step 2, loss = 0.0141
# Epoch 45, step 3, loss = 0.0146
# Epoch 45, step 4, loss = 0.0163
# Epoch 45, step 5, loss = 0.0177
# Epoch 45, step 6, loss = 0.0169
# Epoch 45, step 7, loss = 0.0175
# Epoch 45, step 8, loss = 0.0138
# Epoch 45, step 9, loss = 0.0145
# Epoch 45, step 10, loss = 0.0176
# Epoch 45, step 11, loss = 0.0118
# Epoch 45, step 12, loss = 0.0151
# Epoch 45, step 13, loss = 0.0172
# Epoch 45, step 14, loss = 0.0097
# Epoch 45, level1, accu = 1.0000, f1_score = 1.0000
# Epoch 45, level2, accu = 1.0000, f1_score = 1.0000
# Epoch 45, level3, accu = 0.9999, f1_score = 0.9999
# Epoch 45, level4, accu = 0.9999, f1_score = 0.9999
# ------------------------------------------------------------------
# Epoch 46, step 0, loss = 0.0144
# Epoch 46, step 1, loss = 0.0171
# Epoch 46, step 2, loss = 0.0163
# Epoch 46, step 3, loss = 0.0163
# Epoch 46, step 4, loss = 0.0155
# Epoch 46, step 5, loss = 0.0142
# Epoch 46, step 6, loss = 0.0160
# Epoch 46, step 7, loss = 0.0145
# Epoch 46, step 8, loss = 0.0142
# Epoch 46, step 9, loss = 0.0112
# Epoch 46, step 10, loss = 0.1254
# Epoch 46, step 11, loss = 0.0166
# Epoch 46, step 12, loss = 0.0142
# Epoch 46, step 13, loss = 0.0147
# Epoch 46, step 14, loss = 0.0015
# Epoch 46, level1, accu = 1.0000, f1_score = 1.0000
# Epoch 46, level2, accu = 1.0000, f1_score = 1.0000
# Epoch 46, level3, accu = 0.9999, f1_score = 0.9999
# Epoch 46, level4, accu = 0.9999, f1_score = 0.9999
# ------------------------------------------------------------------
# Epoch 47, step 0, loss = 0.0206
# Epoch 47, step 1, loss = 0.0150
# Epoch 47, step 2, loss = 0.0163
# Epoch 47, step 3, loss = 0.0151
# Epoch 47, step 4, loss = 0.0191
# Epoch 47, step 5, loss = 0.0150
# Epoch 47, step 6, loss = 0.0156
# Epoch 47, step 7, loss = 0.0137
# Epoch 47, step 8, loss = 0.0133
# Epoch 47, step 9, loss = 0.0182
# Epoch 47, step 10, loss = 0.0139
# Epoch 47, step 11, loss = 0.0139
# Epoch 47, step 12, loss = 0.0143
# Epoch 47, step 13, loss = 0.0147
# Epoch 47, step 14, loss = 0.0080
# Epoch 47, level1, accu = 1.0000, f1_score = 1.0000
# Epoch 47, level2, accu = 1.0000, f1_score = 1.0000
# Epoch 47, level3, accu = 1.0000, f1_score = 1.0000
# Epoch 47, level4, accu = 1.0000, f1_score = 1.0000
# ------------------------------------------------------------------
# Epoch 48, step 0, loss = 0.0168
# Epoch 48, step 1, loss = 0.0109
# Epoch 48, step 2, loss = 0.0151
# Epoch 48, step 3, loss = 0.0146
# Epoch 48, step 4, loss = 0.0148
# Epoch 48, step 5, loss = 0.0165
# Epoch 48, step 6, loss = 0.0152
# Epoch 48, step 7, loss = 0.0136
# Epoch 48, step 8, loss = 0.0134
# Epoch 48, step 9, loss = 0.0129
# Epoch 48, step 10, loss = 0.0134
# Epoch 48, step 11, loss = 0.0145
# Epoch 48, step 12, loss = 0.0133
# Epoch 48, step 13, loss = 0.0130
# Epoch 48, step 14, loss = 0.0196
# Epoch 48, level1, accu = 1.0000, f1_score = 1.0000
# Epoch 48, level2, accu = 1.0000, f1_score = 1.0000
# Epoch 48, level3, accu = 1.0000, f1_score = 1.0000
# Epoch 48, level4, accu = 1.0000, f1_score = 1.0000
# ------------------------------------------------------------------
# Epoch 49, step 0, loss = 0.0119
# Epoch 49, step 1, loss = 0.0130
# Epoch 49, step 2, loss = 0.0155
# Epoch 49, step 3, loss = 0.0154
# Epoch 49, step 4, loss = 0.0154
# Epoch 49, step 5, loss = 0.1028
# Epoch 49, step 6, loss = 0.0101
# Epoch 49, step 7, loss = 0.0133
# Epoch 49, step 8, loss = 0.0137
# Epoch 49, step 9, loss = 0.0152
# Epoch 49, step 10, loss = 0.0132
# Epoch 49, step 11, loss = 0.0156
# Epoch 49, step 12, loss = 0.0148
# Epoch 49, step 13, loss = 0.0210
# Epoch 49, step 14, loss = 0.0003
# Epoch 49, level1, accu = 1.0000, f1_score = 1.0000
# Epoch 49, level2, accu = 1.0000, f1_score = 1.0000
# Epoch 49, level3, accu = 0.9999, f1_score = 0.9999
# Epoch 49, level4, accu = 0.9999, f1_score = 0.9999
# ------------------------------------------------------------------
# Epoch 50, step 0, loss = 0.0157
# Epoch 50, step 1, loss = 0.0117
# Epoch 50, step 2, loss = 0.0123
# Epoch 50, step 3, loss = 0.0140
# Epoch 50, step 4, loss = 0.0158
# Epoch 50, step 5, loss = 0.0113
# Epoch 50, step 6, loss = 0.0111
# Epoch 50, step 7, loss = 0.0116
# Epoch 50, step 8, loss = 0.0129
# Epoch 50, step 9, loss = 0.0126
# Epoch 50, step 10, loss = 0.1109
# Epoch 50, step 11, loss = 0.0131
# Epoch 50, step 12, loss = 0.0097
# Epoch 50, step 13, loss = 0.0134
# Epoch 50, step 14, loss = 0.0012
# Epoch 50, level1, accu = 1.0000, f1_score = 1.0000
# Epoch 50, level2, accu = 1.0000, f1_score = 1.0000
# Epoch 50, level3, accu = 0.9999, f1_score = 0.9999
# Epoch 50, level4, accu = 0.9999, f1_score = 0.9999
# ------------------------------------------------------------------
# Epoch 51, step 0, loss = 0.0231
# Epoch 51, step 1, loss = 0.0137
# Epoch 51, step 2, loss = 0.0135
# Epoch 51, step 3, loss = 0.0139
# Epoch 51, step 4, loss = 0.0138
# Epoch 51, step 5, loss = 0.0135
# Epoch 51, step 6, loss = 0.0180
# Epoch 51, step 7, loss = 0.0131
# Epoch 51, step 8, loss = 0.0126
# Epoch 51, step 9, loss = 0.0130
# Epoch 51, step 10, loss = 0.0118
# Epoch 51, step 11, loss = 0.0110
# Epoch 51, step 12, loss = 0.0099
# Epoch 51, step 13, loss = 0.0117
# Epoch 51, step 14, loss = 0.0151
# Epoch 51, level1, accu = 1.0000, f1_score = 1.0000
# Epoch 51, level2, accu = 1.0000, f1_score = 1.0000
# Epoch 51, level3, accu = 0.9999, f1_score = 0.9999
# Epoch 51, level4, accu = 0.9999, f1_score = 0.9999
# ------------------------------------------------------------------
# Epoch 52, step 0, loss = 0.0113
# Epoch 52, step 1, loss = 0.0108
# Epoch 52, step 2, loss = 0.0102
# Epoch 52, step 3, loss = 0.0116
# Epoch 52, step 4, loss = 0.0124
# Epoch 52, step 5, loss = 0.0120
# Epoch 52, step 6, loss = 0.0144
# Epoch 52, step 7, loss = 0.0104
# Epoch 52, step 8, loss = 0.0112
# Epoch 52, step 9, loss = 0.0102
# Epoch 52, step 10, loss = 0.0132
# Epoch 52, step 11, loss = 0.0108
# Epoch 52, step 12, loss = 0.0124
# Epoch 52, step 13, loss = 0.0131
# Epoch 52, step 14, loss = 0.0062
# Epoch 52, level1, accu = 1.0000, f1_score = 1.0000
# Epoch 52, level2, accu = 1.0000, f1_score = 1.0000
# Epoch 52, level3, accu = 1.0000, f1_score = 1.0000
# Epoch 52, level4, accu = 1.0000, f1_score = 1.0000
# ------------------------------------------------------------------
# Epoch 53, step 0, loss = 0.0103
# Epoch 53, step 1, loss = 0.0105
# Epoch 53, step 2, loss = 0.0108
# Epoch 53, step 3, loss = 0.0116
# Epoch 53, step 4, loss = 0.0093
# Epoch 53, step 5, loss = 0.0105
# Epoch 53, step 6, loss = 0.0108
# Epoch 53, step 7, loss = 0.0112
# Epoch 53, step 8, loss = 0.0105
# Epoch 53, step 9, loss = 0.0122
# Epoch 53, step 10, loss = 0.0110
# Epoch 53, step 11, loss = 0.0121
# Epoch 53, step 12, loss = 0.0107
# Epoch 53, step 13, loss = 0.0133
# Epoch 53, step 14, loss = 0.0119
# Epoch 53, level1, accu = 1.0000, f1_score = 1.0000
# Epoch 53, level2, accu = 1.0000, f1_score = 1.0000
# Epoch 53, level3, accu = 1.0000, f1_score = 1.0000
# Epoch 53, level4, accu = 1.0000, f1_score = 1.0000
# ------------------------------------------------------------------
# Epoch 54, step 0, loss = 0.0116
# Epoch 54, step 1, loss = 0.0110
# Epoch 54, step 2, loss = 0.0098
# Epoch 54, step 3, loss = 0.0110
# Epoch 54, step 4, loss = 0.0098
# Epoch 54, step 5, loss = 0.0090
# Epoch 54, step 6, loss = 0.0097
# Epoch 54, step 7, loss = 0.0119
# Epoch 54, step 8, loss = 0.0090
# Epoch 54, step 9, loss = 0.0106
# Epoch 54, step 10, loss = 0.0094
# Epoch 54, step 11, loss = 0.0114
# Epoch 54, step 12, loss = 0.0104
# Epoch 54, step 13, loss = 0.0112
# Epoch 54, step 14, loss = 0.0031
# Epoch 54, level1, accu = 1.0000, f1_score = 1.0000
# Epoch 54, level2, accu = 1.0000, f1_score = 1.0000
# Epoch 54, level3, accu = 1.0000, f1_score = 1.0000
# Epoch 54, level4, accu = 1.0000, f1_score = 1.0000
# ------------------------------------------------------------------
# Epoch 55, step 0, loss = 0.0090
# Epoch 55, step 1, loss = 0.0101
# Epoch 55, step 2, loss = 0.0103
# Epoch 55, step 3, loss = 0.0100
# Epoch 55, step 4, loss = 0.0088
# Epoch 55, step 5, loss = 0.0109
# Epoch 55, step 6, loss = 0.0098
# Epoch 55, step 7, loss = 0.0089
# Epoch 55, step 8, loss = 0.0103
# Epoch 55, step 9, loss = 0.0100
# Epoch 55, step 10, loss = 0.0105
# Epoch 55, step 11, loss = 0.0091
# Epoch 55, step 12, loss = 0.0102
# Epoch 55, step 13, loss = 0.0096
# Epoch 55, step 14, loss = 0.0337
# Epoch 55, level1, accu = 1.0000, f1_score = 1.0000
# Epoch 55, level2, accu = 1.0000, f1_score = 1.0000
# Epoch 55, level3, accu = 1.0000, f1_score = 1.0000
# Epoch 55, level4, accu = 1.0000, f1_score = 1.0000
# ------------------------------------------------------------------
# Epoch 56, step 0, loss = 0.0087
# Epoch 56, step 1, loss = 0.0103
# Epoch 56, step 2, loss = 0.0113
# Epoch 56, step 3, loss = 0.0110
# Epoch 56, step 4, loss = 0.0095
# Epoch 56, step 5, loss = 0.0100
# Epoch 56, step 6, loss = 0.0117
# Epoch 56, step 7, loss = 0.0139
# Epoch 56, step 8, loss = 0.0108
# Epoch 56, step 9, loss = 0.0113
# Epoch 56, step 10, loss = 0.0096
# Epoch 56, step 11, loss = 0.0112
# Epoch 56, step 12, loss = 0.0099
# Epoch 56, step 13, loss = 0.0098
# Epoch 56, step 14, loss = 0.0184
# Epoch 56, level1, accu = 1.0000, f1_score = 1.0000
# Epoch 56, level2, accu = 1.0000, f1_score = 1.0000
# Epoch 56, level3, accu = 1.0000, f1_score = 1.0000
# Epoch 56, level4, accu = 1.0000, f1_score = 1.0000
# ------------------------------------------------------------------
# Epoch 57, step 0, loss = 0.0096
# Epoch 57, step 1, loss = 0.0094
# Epoch 57, step 2, loss = 0.0078
# Epoch 57, step 3, loss = 0.0089
# Epoch 57, step 4, loss = 0.0122
# Epoch 57, step 5, loss = 0.0093
# Epoch 57, step 6, loss = 0.0095
# Epoch 57, step 7, loss = 0.0092
# Epoch 57, step 8, loss = 0.0080
# Epoch 57, step 9, loss = 0.0079
# Epoch 57, step 10, loss = 0.0105
# Epoch 57, step 11, loss = 0.0089
# Epoch 57, step 12, loss = 0.0088
# Epoch 57, step 13, loss = 0.0073
# Epoch 57, step 14, loss = 0.0009
# Epoch 57, level1, accu = 1.0000, f1_score = 1.0000
# Epoch 57, level2, accu = 1.0000, f1_score = 1.0000
# Epoch 57, level3, accu = 1.0000, f1_score = 1.0000
# Epoch 57, level4, accu = 1.0000, f1_score = 1.0000
# ------------------------------------------------------------------
# Epoch 58, step 0, loss = 0.0106
# Epoch 58, step 1, loss = 0.0092
# Epoch 58, step 2, loss = 0.0090
# Epoch 58, step 3, loss = 0.0096
# Epoch 58, step 4, loss = 0.0076
# Epoch 58, step 5, loss = 0.0089
# Epoch 58, step 6, loss = 0.0084
# Epoch 58, step 7, loss = 0.0091
# Epoch 58, step 8, loss = 0.0081
# Epoch 58, step 9, loss = 0.0085
# Epoch 58, step 10, loss = 0.0069
# Epoch 58, step 11, loss = 0.0090
# Epoch 58, step 12, loss = 0.0082
# Epoch 58, step 13, loss = 0.0076
# Epoch 58, step 14, loss = 0.0183
# Epoch 58, level1, accu = 1.0000, f1_score = 1.0000
# Epoch 58, level2, accu = 1.0000, f1_score = 1.0000
# Epoch 58, level3, accu = 1.0000, f1_score = 1.0000
# Epoch 58, level4, accu = 1.0000, f1_score = 1.0000
# ------------------------------------------------------------------
# Epoch 59, step 0, loss = 0.0083
# Epoch 59, step 1, loss = 0.0091
# Epoch 59, step 2, loss = 0.0076
# Epoch 59, step 3, loss = 0.0088
# Epoch 59, step 4, loss = 0.0084
# Epoch 59, step 5, loss = 0.0084
# Epoch 59, step 6, loss = 0.0079
# Epoch 59, step 7, loss = 0.0074
# Epoch 59, step 8, loss = 0.0085
# Epoch 59, step 9, loss = 0.0084
# Epoch 59, step 10, loss = 0.0091
# Epoch 59, step 11, loss = 0.0079
# Epoch 59, step 12, loss = 0.0086
# Epoch 59, step 13, loss = 0.0078
# Epoch 59, step 14, loss = 0.0027
# Epoch 59, level1, accu = 1.0000, f1_score = 1.0000
# Epoch 59, level2, accu = 1.0000, f1_score = 1.0000
# Epoch 59, level3, accu = 1.0000, f1_score = 1.0000
# Epoch 59, level4, accu = 1.0000, f1_score = 1.0000
# ------------------------------------------------------------------

# %%
plt.figure(figsize=(10,7))
plt.plot(loss_list)
plt.xlabel("num_iterations")
plt.ylabel("loss")
plt.title("train loss of GCN Method")
plt.show()

plt.figure(figsize=(10*2,7*4))
for i in range(4):
    plt.subplot(4,2,i+1)
    plt.title("Level %d of GCN Method"%(i+1))
    plt.plot(accu_list[i], "-", color="red", label = "accu")
    plt.plot(f1_list[i], "-.", color="green", label = "F1_score")
    plt.xlabel("num_epochss")
    plt.ylabel("value")
    plt.legend()
plt.show()

# %%
def valid(model = model, classifiers = classifiers, criterion = criterion, dataloader = dataloader_valid, label_df = valid_label_df):
    model.eval()

    val_preds = []
    val_labels = []
    for i in range(len(classifiers)):
        val_preds.append(None)
        val_labels.append(None)
    for step, batch in enumerate(dataloader):
        data = batch[0]
        eps, adj = GetAdjacency(data, 11, epsilon)
        data = data.to(device)
        adj = torch.from_numpy(adj).to(device)
        label = batch[1]
        for i in range(len(label)):
            label[i] = label[i].to(device)
            if val_labels[i] is None:
                val_labels[i] = label[i].clone().squeeze(-1).data.cpu().argmax(dim=1)
            else:
                val_labels[i] = torch.cat((val_labels[i], label[i].clone().squeeze(-1).data.cpu().argmax(dim=1)), dim=0)
                
        with torch.no_grad():       
            output = model(adj, data)
            loss = None
            for i in range(len(classifiers)):
                result = classifiers[i](output)
                preds = torch.softmax(result, dim=1).data.cpu().argmax(dim=1)
                if(val_preds[i] is None):
                    val_preds[i] = preds
                else:
                    val_preds[i] = torch.cat((val_preds[i], preds), dim=0)
        
    level_f1 = []
    level_accu = []
    for i in range(len(classifiers)):
        level_f1.append(f1_score(val_labels[i], val_preds[i], average="macro"))
        level_accu.append(accuracy_score(val_labels[i], val_preds[i]))
        print("level%d, accu = %.4f, f1_score = %.4f"%(i+1, level_accu[i], level_f1[i]))
    
    label_pd = label_df.copy()
    for i in range(len(classifiers)):
        for j in range(label_pd.shape[0]):
            label_pd.iloc[j,i] = level_label_value[i+1][val_preds[i][j].item()]
    label_pd = label_pd.drop(label_pd.columns[[i for i in range(4, label_pd.shape[1])]], axis=1)
    label_pd.columns = ["cell_type_level%d"%(i+1) for i in range(len(classifiers))]
    return label_pd

# %%
print("valid results:")
valid_preds = valid()
valid_preds.to_csv("./menon_validation_preds_GCN.csv")
# Out:
# valid results:
# level1, accu = 0.9998, f1_score = 0.9615
# level2, accu = 0.9971, f1_score = 0.9975
# level3, accu = 0.9833, f1_score = 0.9730
# level4, accu = 0.9806, f1_score = 0.9697

# %%
def test(model = model, classifiers = classifiers, criterion = criterion, dataloader = dataloader_test, label_df = test_data_df):
    model.eval()

    val_preds = []
    val_labels = []
    for i in range(len(classifiers)):
        val_preds.append(None)
        val_labels.append(None)
    for step, batch in enumerate(dataloader):
        data = batch[0]
        eps, adj = GetAdjacency(data, 11, epsilon)
        data = data.to(device)
        adj = torch.from_numpy(adj).to(device)
                
        with torch.no_grad():       
            output = model(adj, data)
            loss = None
            for i in range(len(classifiers)):
                result = classifiers[i](output)
                preds = torch.softmax(result, dim=1).data.cpu().argmax(dim=1)
                if(val_preds[i] is None):
                    val_preds[i] = preds
                else:
                    val_preds[i] = torch.cat((val_preds[i], preds), dim=0)
    
    label_pd = label_df.copy()
    for i in range(len(classifiers)):
        for j in range(label_pd.shape[0]):
            label_pd.iloc[j,i] = level_label_value[i+1][val_preds[i][j].item()]
    label_pd = label_pd.drop(label_pd.columns[[i for i in range(4, label_pd.shape[1])]], axis=1)
    label_pd.columns = ["cell_type_level%d"%(i+1) for i in range(len(classifiers))]
    return label_pd

# %%
test_data_df.shape
# Out:
# (21979, 2000)

# %%
test_preds = test()
test_preds.to_csv("./lukowski_test_preds_GCN.csv")

# %% [markdown]
# # 可视化与聚类

# %%
def get_embedding(model = model, classifiers = classifiers, dataloader = dataloader_train):
    flag = torch.tensor(-1)
    model.eval()
    
    embedding = None
    labels = []
    for i in range(len(classifiers)):
        labels.append(None)
    
    for step, batch in enumerate(dataloader):
        data = batch[0]
        eps, adj = GetAdjacency(data, 11, epsilon)
        data = data.to(device)
        adj = torch.from_numpy(adj).to(device)
        label = batch[1]
        if(not label[0].dtype == flag.dtype):
            for i in range(len(label)):
                label[i] = label[i].to(device)
                if labels[i] is None:
                    labels[i] = label[i].clone().squeeze(-1).data.cpu()
                else:
                    labels[i] = torch.cat((labels[i], label[i].clone().squeeze(-1).data.cpu()), dim=0)
        
        with torch.no_grad():       
            output = model(adj, data)
            if(embedding is None):
                embedding = output.data.cpu()
            else:
                embedding = torch.cat((embedding, output.data.cpu()), dim=0)
                
    embedding = np.array(embedding)
    if(not label[0].dtype == flag.dtype):
        for i in range(len(labels)):
            labels[i] = np.array(labels[i])
    
    return embedding, labels

# %%
def get_data(classifiers = classifiers, dataloader = dataloader_train):
    flag = torch.tensor(-1)
    model.eval()
    
    embedding = None
    labels = []
    for i in range(len(classifiers)):
        labels.append(None)
    
    for step, batch in enumerate(dataloader):
        data = batch[0].to(device)
        label = batch[1]
        if(embedding is None):
            embedding = data.data.cpu()
        else:
            embedding = torch.cat((embedding, data.data.cpu()), dim=0)
        
        if(not label[0].dtype == flag.dtype):
            for i in range(len(label)):
                
                label[i] = label[i].to(device)
                if labels[i] is None:
                    labels[i] = label[i].clone().squeeze(-1).data.cpu()
                else:
                    labels[i] = torch.cat((labels[i], label[i].clone().squeeze(-1).data.cpu()), dim=0)

                
    embedding = np.array(embedding)
    if(not label[0].dtype == flag.dtype):
        for i in range(len(labels)):
            labels[i] = np.array(labels[i])
    
    return embedding, labels

# %%
data_train, labels_train = get_data()
data_valid, labels_valid = get_data(dataloader = dataloader_valid)
data_test, labels_test = get_data(dataloader = dataloader_test)

# %%
__tsne = TSNE(n_components=2, n_iter=1000, metric='euclidean', random_state = 42)
__dots = __tsne.fit_transform(data_train)
__tsne2 = TSNE(n_components=2, n_iter=1000, metric='euclidean', random_state = 42)
__dots_tr_val = __tsne2.fit_transform(np.concatenate([data_train, data_valid], axis=0))
__tsne3 = TSNE(n_components=2, n_iter=1000, metric='euclidean', random_state = 42)
__dots_tr_val_te = __tsne3.fit_transform(np.concatenate([data_train, data_valid, data_test], axis=0))

# %%
plt.figure(figsize=(10,10))
plt.plot(__dots[:,0],__dots[:,1],".", color = "red")
plt.show()

plt.figure(figsize=(10,10))
plt.plot(__dots_tr_val[:data_train.shape[0],0],__dots_tr_val[:data_train.shape[0],1],".", color = "red", label = "menon_train")
plt.plot(__dots_tr_val[data_train.shape[0]:,0],__dots_tr_val[data_train.shape[0]:,1],".", color = "green", label = "menon_valid")
plt.legend()
plt.show()

plt.figure(figsize=(10,10))
index1 = data_train.shape[0]
index2 = data_train.shape[0]+data_valid.shape[0]
plt.plot(__dots_tr_val_te[:index1,0],__dots_tr_val_te[:index1,1],".", color = "red", label = "menon_train")
plt.plot(__dots_tr_val_te[index1:index2,0],__dots_tr_val_te[index1:index2,1],".", color = "green", label = "menon_valid")
plt.plot(__dots_tr_val_te[index2:,0],__dots_tr_val_te[index2:,1],".", color = "blue", label = "lukowski_test")
plt.legend()
plt.show()

# %% [markdown]
# ## train_data

# %%
embedding_train, labels_train = get_embedding()

# %%
_tsne = TSNE(n_components=2, n_iter=1000, metric='euclidean', random_state = 42)
_dots = _tsne.fit_transform(embedding_train)

# %%
plt.figure(figsize=(10,10))
plt.plot(_dots[:,0],_dots[:,1],".")
plt.show()

# %%
tsne = TSNE(n_components=2, n_iter=1000, metric='cosine', random_state = 42)
dots = tsne.fit_transform(embedding_train)
# Out:
# /home/cuiyanfei/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_t_sne.py:691: FutureWarning: 'square_distances' has been introduced in 0.24 to help phase out legacy squaring behavior. The 'legacy' setting will be removed in 1.1 (renaming of 0.26), and the default setting will be changed to True. In 1.3, 'square_distances' will be removed altogether, and distances will be squared by default. Set 'square_distances'=True to silence this warning.
#   warnings.warn(

# %%
plt.figure(figsize=(10,10))
plt.plot(dots[:,0],dots[:,1],".")
plt.show()

# %%
for level in range(len(level_label_value)-1):
    plt.figure(figsize=(10,10))
    colors = ["red", "green", "blue", "purple", "orange", "black"]
    for i in range(labels_train[level].shape[1]):
        tmp_label = level_label_value[level+1][i]
        idxs = np.where(labels_train[level][:, i]==1)[0]
        plt.plot(dots[idxs,0], dots[idxs,1], ".", color=colors[i], label=tmp_label)
    plt.legend(loc='lower left')
    plt.show()
