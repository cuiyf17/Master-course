# %%
import os
import sys
sys.path.append(os.path.abspath('/home/cuiyf/myalphasim/'))
from cuiyf_op.visualization import simsummary, bcorr, visual_summary

# %%
pnl_path = "/home/cuiyf/myalphasim/Basic/pnl/alpha.CorrCloseAmount"

# %%
visual_summary(pnl_path)
# Out:
#             dates long(M) short(M)  pnl(M)    %ret    %tvr      shrp (IR)   %dd  %win fitness   ddStart     ddEnd
# 20100104-20101231   10.00   -10.00   0.611    5.91   27.85    0.72( 0.05)  7.82  0.55    0.33  20100929  20101015
# 20110104-20111230   10.00   -10.00   1.928   19.12   26.25    2.74( 0.18)  2.90  0.55    2.34  20110429  20110526
# 20120104-20121231   10.00   -10.00   2.179   21.70   25.11    3.23( 0.21)  4.31  0.57    3.00  20120109  20120118
# 20130104-20131231   10.00   -10.00   1.494   15.19   24.52    2.12( 0.14)  7.33  0.54    1.67  20130712  20130912
# 20140102-20141231   10.00   -10.00  -0.574   -5.67   23.61   -0.90(-0.06)  9.46  0.52   -0.44  20140113  20141222
# 20150105-20151231   10.00   -10.00   2.733   27.10   23.64    2.29( 0.15) 11.39  0.60    2.45  20150709  20150819
# 20160104-20161230   10.00   -10.00   1.072   10.63   24.40    1.95( 0.13)  5.62  0.55    1.29  20160118  20160307
# ...

# %%
base_paths = ["/home/cuiyf/myalphasim/Basic/pnl/",
              "/home/cuiyf/myalphasim/Barra/pnl/"
              ]
bcorr(pnl_path, base_paths)
# Out:
# /home/cuiyf/myalphasim/Basic/pnl:
#     alpha.CorrCloseAmount: 1.000000
#     alpha.20dr           : 0.352099
#     alpha.5dr            : 0.257766
#     alpha.MeanAmount     : 0.098147
# /home/cuiyf/myalphasim/Barra/pnl:
#     alpha.BarraMomentum          : 0.103176
#     alpha.BarraNonLinearSize     : -0.328943
#     alpha.BarraBeta              : -0.361784
#     alpha.BarraSize              : 0.330851
#     alpha.BarraLiquidity         : -0.373096
#     alpha.BarraResidualVolatility: -0.199399
